# %%
#Task2: Descriptive Analysis
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#IMPORT Updataed data from task1
df = pd.read_csv('D:\JOB and Internship\internship congify\Dataset .csv')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\J'
# <>:2: SyntaxWarning: invalid escape sequence '\J'
# C:\Users\Vipul\AppData\Local\Temp\ipykernel_11308\4116286329.py:2: SyntaxWarning: invalid escape sequence '\J'
#   df = pd.read_csv('D:\JOB and Internship\internship congify\Dataset .csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9542 entries, 0 to 9541
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9542 non-null   int64
#  1   Restaurant Name       9542 non-null   object
#  2   Country Code          9542 non-null   int64
#  3   City                  9542 non-null   object
#  4   Address               9542 non-null   object
#  5   Locality              9542 non-null   object
#  6   Locality Verbose      9542 non-null   object
#  7   Longitude             9542 non-null   float64
#  8   Latitude              9542 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9542 non-null   int64
#  11  Currency              9542 non-null   object
#  12  Has Table booking     9542 non-null   object
#  13  Has Online delivery   9542 non-null   object
#  14  Is delivering now     9542 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.542000e+03   9542.000000  9542.000000  9542.000000
# mean    9.043301e+06     18.179208    64.274997    25.848532
# std     8.791967e+06     56.451600    41.197602    11.010094
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019312e+05      1.000000    77.081565    28.478658
# 50%     6.002726e+06      1.000000    77.192031    28.570444
# 75%     1.835260e+07      1.000000    77.282043    28.642711
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9542.000000  9542.000000       9542.000000   9542.000000
# mean            1200.326137     1.804968          2.665238    156.772060
# std            16128.743876     0.905563          1.516588    430.203324
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df['City'].value_counts()
# Out:
# City
# New Delhi         5473
# Gurgaon           1118
# Noida             1080
# Faridabad          251
# Ghaziabad           25
#                   ...
# Lincoln              1
# Lakeview             1
# Lakes Entrance       1
# Inverloch            1
# Panchkula            1
# Name: count, Length: 140, dtype: int64

# %%
df[df['City']=='New Delhi']
# Out:
#       Restaurant ID       Restaurant Name  Country Code       City  \
# 2551       18287358            Food Cloud             1  New Delhi
# 2552       18216944             Burger.in             1  New Delhi
# 2553         313333       Days of the Raj             1  New Delhi
# 2554       18384127        Dilli Ka Dhaba             1  New Delhi
# 2555            582             Govardhan             1  New Delhi
# ...             ...                   ...           ...        ...
# 8019       18445274          Motu N Patlu             1  New Delhi
# 8020       18168147        S.K. Fast Food             1  New Delhi
# 8021       18429375    Sufiyan Restaurant             1  New Delhi
# 8022         310479       The Relax Point             1  New Delhi
# 8023       18212160  Zareen's Dastarkhwan             1  New Delhi
#
#                                                 Address     Locality  \
# 2551                              Aaya Nagar, New Delhi   Aaya Nagar
# ...

# %%
#finding the country code of each city
city_country_mapping = df.groupby("City")["Country Code"].first()
print(city_country_mapping)
# Out:
# City
# Abu Dhabi          214
# Agra                 1
# Ahmedabad            1
# Albany             216
# Allahabad            1
#                   ...
# Weirton            216
# Wellington City    148
# Winchester Bay     216
# Yorkton             37
# ��stanbul          208
# Name: Country Code, Length: 140, dtype: int64

# %%
country_counts = df["Country Code"].value_counts().head(10)  # Top 10 countries

# Plot
plt.figure(figsize=(10, 5))
sns.barplot(x=country_counts.index, y=country_counts.values, palette="viridis")
plt.xlabel("Country Code")
plt.ylabel("Number of Restaurants")
plt.title("Top 10 Countries with Most Restaurants")
plt.show()
# Out:
# C:\Users\Vipul\AppData\Local\Temp\ipykernel_11308\1540670916.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=country_counts.index, y=country_counts.values, palette="viridis")

# %%
count_city = df['City'].value_counts().head(10)

plt.figure(figsize=(10, 5))
sns.barplot(x=count_city.index, y=count_city.values, palette="viridis")
plt.xlabel("City")
plt.ylabel("Number of Restaurants")
plt.title("Top 10 Cities with Most Restaurants")
plt.show()
# Out:
# C:\Users\Vipul\AppData\Local\Temp\ipykernel_11308\256634411.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=count_city.index, y=count_city.values, palette="viridis")

# %%
count_Cuisine = df['Cuisines'].value_counts().head(10)

plt.figure(figsize=(10, 5))
sns.barplot(x=count_Cuisine.index, y=count_Cuisine.values, palette="viridis")
plt.xticks(rotation=90)
plt.xlabel("Cuisine")
plt.ylabel("Number of Restaurants")
plt.title("Top 10 Cuisines")
plt.show()
# Out:
# C:\Users\Vipul\AppData\Local\Temp\ipykernel_11308\3672878975.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=count_Cuisine.index, y=count_Cuisine.values, palette="viridis")
